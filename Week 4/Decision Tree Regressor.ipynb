# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
# Importing Dataset

df = pd.read_csv('medical-charges.csv')

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Basic Exploration

# %%
# Basic Exploration

print("Information : \n")
print(df.info())

print("\nMissing Values : \n")
print(df.isnull().sum())

print("\nDuplicate Entries : \n")
print(df.duplicated().sum())
# Out:
# Information :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None
#
# Missing Values :
#
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64
#
# Duplicate Entries :
#
# 1

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Splitting the Data

# %%
# Training data and Testing data

x = df.drop('charges', axis = 1)
y = df['charges']

x_train,x_test,y_train,y_test = train_test_split(x,y,
                                                test_size = 0.2,
                                                random_state = 20)

# %% [markdown]
# ### Data Transformation

# %%
# Encoding the Data

trf1 = ColumnTransformer(transformers = [
    ('onehot',OneHotEncoder(handle_unknown = 'ignore', drop = 'if_binary'),['sex','smoker','region'])
], remainder = 'passthrough')

# %% [markdown]
# # Model - Decision Tree Regressor

# %%
# Object for a Model

model = DecisionTreeRegressor()

# %%
# Creating Pipeline for a model

pipe = Pipeline([
    ('transform', trf1),
    ('model', model)
])

# %% [markdown]
# ### Training the Model

# %%
# Training the Model

pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore'),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model', DecisionTreeRegressor())])

# %% [markdown]
# ### Prediction & Evaluation

# %%
# Predictions

prediction1 = pipe.predict(x_test)

# Evaluation
print("R2 Score : ",r2_score(y_test,prediction1))
print("MAE : ",mean_absolute_error(y_test,prediction1))
# Out:
# R2 Score :  0.805511778613996
# MAE :  2474.1733845671642

# %% [markdown]
# # Hyperparameter Tuning

# %%
model2 = DecisionTreeRegressor()

# %%
pipe2 = Pipeline([
    ('transform',trf1),
    ('model',model2)
])

# %%
param_grid = {
    'model__max_depth' : [None,3,5,7,10],
    'model__min_samples_split' : [2,5,10],
    'model__min_samples_leaf' : [1,2,5],
    'model__criterion' : ['squared_error','absolute_error']
}

grid_search = GridSearchCV(
    estimator = pipe2,
    param_grid = param_grid,
    cv = 5,
    n_jobs = -1
)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transform',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehot',
#                                                                          OneHotEncoder(drop='if_binary',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['sex',
#                                                                           'smoker',
#                                                                           'region'])])),
#                                        ('model', DecisionTreeRegressor())]),
#              n_jobs=-1,
#              param_grid={'model__criterion': ['squared_error',
#                                               'absolute_error'],
# ...

# %%
prediction2 = grid_search.predict(x_test)

# %%
# Evaluation
print("R2 Score : ",r2_score(y_test,prediction2))
print("MAE : ",mean_absolute_error(y_test,prediction2))
# Out:
# R2 Score :  0.9039603642505487
# MAE :  1588.4470605932836

# %%
# The specific params that won
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'model__criterion': 'absolute_error', 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 2}

# %%
# Plotting the Decision Tree

best_pipe = grid_search.best_estimator_
model = best_pipe.named_steps['model']
transformer = best_pipe.named_steps['transform']


feature_names = transformer.get_feature_names_out()

plt.figure(figsize=(25, 12))  
plot_tree(
    model, 
    feature_names=feature_names, 
    filled=True,            
    rounded=True, 
    fontsize=10,
    precision=2             
)

plt.title("Decision Tree Regressor (Depth 5)", fontsize=20)
plt.show()
